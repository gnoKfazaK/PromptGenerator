# %%
# !uv pip install datasets
# Out:
# Using Python 3.12.12 environment at: /usr
# Audited 1 package in 335ms

# %%
from datasets import load_dataset

# %%
import os
from dotenv import load_dotenv

load_dotenv()

# print(os.getenv("HUGGINGFACETOKEN"))
dataset = load_dataset("SoftAge-AI/prompt-eng_dataset", token = "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")
# Out:
# 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

# %%
import pandas as pd

data = pd.DataFrame(dataset)

# %%
data['train'][0].keys()
# Out:
# dict_keys(['S.No.', 'Prompt', 'Category', 'Type'])

# %%
dataset['train'].num_rows
# Out:
# 1001

# %%
category = set()
for i in range(dataset['train'].num_rows):
  category.add(data['train'][i]['Category'])

category
# Out:
# {'Classification',
#  'Coding',
#  'Data manipulation',
#  'Language Translation',
#  'Logical Reasoning',
#  'Open ended QA',
#  'Problem solving',
#  'Roleplaying',
#  'Text Summarization',
#  'Writing'}
